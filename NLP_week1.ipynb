# %%
nltk.corpus.gutenberg.abspath('shakespeare-hamlet.txt')
# Out:
# FileSystemPathPointer('/root/nltk_data/corpora/gutenberg/shakespeare-hamlet.txt')

# %%
# !cp /root/nltk_data/corpora/gutenberg/shakespeare-hamlet.txt /content/sample_data/shake.txt

# %% [markdown]
# # Chap 1
# 1.1-1.4

# %% [markdown]
# ## 1.2   Getting Started with NLTK

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
# ...

# %%
nltk.__version__
# Out:
# '3.2.5'

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.name
# Out:
# 'Moby Dick by Herman Melville 1851'

# %%
text1.tokens[100:110]
# Out:
# ['and', 'to', 'teach', 'them', 'by', 'what', 'name', 'a', 'whale', '-']

# %%
text1.count('Moby')
# Out:
# 84

# %%
text1.vocab()['Moby']
# Out:
# 84

# %%
text1.vocab().most_common(10)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982)]

# %% [markdown]
# ## 1.3   Searching Text

# %%
text1.findall("<.*><.*><monstrous>")
# Out:
# a most monstrous; Touching that monstrous; array of monstrous;
# wondered what monstrous; ; most monstrous; as a monstrous; with the
# monstrous; still more monstrous; of this monstrous; of a monstrous

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.collocations(num=5)
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text2.common_contexts(["monstrous"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad is_fond was_happy a_deal

# %%
text2.common_contexts(["very"])
# Out:
# a_advanced was_young and_fond was_well husband_gravely a_convenient
# a_comfortable live_comfortably is_true is_stout a_serious
# be_inconvenient be_strange a_pleasant we_well had_early was_much
# died_rich is_amiable drawings_much

# %%
from matplotlib import pyplot as plt

ax = plt.figure(figsize=(15,8))
ax.set_facecolor('white')
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America","liberty", "constitution"])

# %%
ax = plt.figure(figsize=(15,8))
ax.set_facecolor('white')
text1.vocab().plot(50, cumulative=False)

# %% [markdown]
# ## 1.4   Counting Vocabulary

# %%
len(text3)
# Out:
# 44764

# %%
len(set(text3))
# Out:
# 2789

# %%
sorted(set(text3))[:20]
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech']

# %%
100 * text4.count('a') / len(text4)
# Out:
# 1.457973123627309

# %%
100 * text4.vocab()['a'] / len(text4)
# Out:
# 1.457973123627309

# %%
def word_freq_percent(word, text):
  freq = 100 * text.count(word) / len(text)
  return freq 

def lexical_diversity(text):
  return len(set(text)) / len(text)

# %%
word_freq_percent('a', text4)
# Out:
# 1.457973123627309

# %%
for t in [text1,text2,text3,text4]:
  print(f"<{t.name}>",len(t),lexical_diversity(t))
# Out:
# <Moby Dick by Herman Melville 1851> 260819 0.07406285585022564
# <Sense and Sensibility by Jane Austen 1811> 141576 0.04826383002768831
# <The Book of Genesis> 44764 0.06230453042623537
# <Inaugural Address Corpus> 149797 0.06617622515804722

# %% [markdown]
# # Chap 2
# https://www.nltk.org/book/ch02.html#sec-conditional-frequency-distributions

# %% [markdown]
# ## 2.1 Gutenberg Corpus

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')
len(emma)
# Out:
# 192427

# %%
emma = nltk.Text(nltk.corpus.gutenberg.words('austen-emma.txt'))
emma.concordance("surprize")
# Out:
# Displaying 25 of 37 matches:
# er father , was sometimes taken by surprize at his being still able to pity `
# hem do the other any good ." " You surprize me ! Emma must do Harriet good : a
# Knightley actually looked red with surprize and displeasure , as he stood up ,
# r . Elton , and found to his great surprize , that Mr . Elton was actually on
# d aid ." Emma saw Mrs . Weston ' s surprize , and felt that it must be great ,
# father was quite taken up with the surprize of so sudden a journey , and his f
# y , in all the favouring warmth of surprize and conjecture . She was , moreove
# he appeared , to have her share of surprize , introduction , and pleasure . Th
# ir plans ; and it was an agreeable surprize to her , therefore , to perceive t
# talking aunt had taken me quite by surprize , it must have been the death of m
# f all the dialogue which ensued of surprize , and inquiry , and congratulation
# ...

# %%
from nltk.corpus import gutenberg
emma = gutenberg.words('austen-emma.txt')

# %%
for fileid in gutenberg.fileids():
  num_chars = len(gutenberg.raw(fileid))
  num_words = len(gutenberg.words(fileid))
  num_sents = len(gutenberg.sents(fileid))
  num_vocab = len(set(w.lower() for w in gutenberg.words(fileid)))
  # average word length, average sentence length, lexical diversity score
  print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)
# Out:
# 5 25 26 austen-emma.txt
# 5 26 17 austen-persuasion.txt
# 5 28 22 austen-sense.txt
# 4 34 79 bible-kjv.txt
# 5 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 18 12 burgess-busterbrown.txt
# 4 20 13 carroll-alice.txt
# 5 20 12 chesterton-ball.txt
# 5 23 11 chesterton-brown.txt
# 5 18 11 chesterton-thursday.txt
# 4 21 25 edgeworth-parents.txt
# 5 26 15 melville-moby_dick.txt
# 5 52 11 milton-paradise.txt
# 4 12 9 shakespeare-caesar.txt
# 4 12 8 shakespeare-hamlet.txt
# 4 12 7 shakespeare-macbeth.txt
# 5 36 12 whitman-leaves.txt

# %%
macbeth_sentences = gutenberg.sents('shakespeare-macbeth.txt')
macbeth_sentences
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']'], ['Actus', 'Primus', '.'], ...]

# %%
longest_len = max([len(s) for s in macbeth_sentences]) #158
[s for s in macbeth_sentences if len(s) == longest_len][0][:10]
# Out:
# ['Doubtfull',
#  'it',
#  'stood',
#  ',',
#  'As',
#  'two',
#  'spent',
#  'Swimmers',
#  ',',
#  'that']

# %% [markdown]
# ## 2.2 Web and Chat Text

# %%
from nltk.corpus import webtext
for fileid in webtext.fileids():
  print(fileid, webtext.raw(fileid)[:65], '...')
# Out:
# firefox.txt Cookie Manager: "Don't allow sites that set removed cookies to se ...
# grail.txt SCENE 1: [wind] [clop clop clop]
# KING ARTHUR: Whoa there!  [clop ...
# overheard.txt White guy: So, do you have any plans for this evening?
# Asian girl ...
# pirates.txt PIRATES OF THE CARRIBEAN: DEAD MAN'S CHEST, by Ted Elliott & Terr ...
# singles.txt 25 SEXY MALE, seeks attrac older single lady, for discreet encoun ...
# wine.txt Lovely delicate, fragrant Rhone wine. Polished leather and strawb ...

# %%
from nltk.corpus import nps_chat
chatroom = nps_chat.posts('10-19-20s_706posts.xml')
chatroom[123]
# Out:
# ['i',
#  'do',
#  "n't",
#  'want',
#  'hot',
#  'pics',
#  'of',
#  'a',
#  'female',
#  ',',
#  'I',
#  'can',
#  'look',
#  'in',
#  'a',
#  'mirror',
#  '.']

# %% [markdown]
# ## 2.3 Brown Corpus

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.fileids()[:10]
# Out:
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10']

# %%
brown.sents(categories='news')
# Out:
# [['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ...]

# %%
brown.words(fileids=['cg22'])
# Out:
# ['Does', 'our', 'society', 'have', 'a', 'runaway', ',', ...]

# %%
news_text = brown.words(categories='news')
fdist = nltk.FreqDist([w.lower() for w in news_text])
modals = ['can', 'could', 'may', 'might', 'must', 'will']
for m in modals:
  print(m + ':', fdist[m], end=' ')
# Out:
# can: 94 could: 87 may: 93 might: 38 must: 53 will: 389

# %%
cfd = nltk.ConditionalFreqDist([(genre, word)
  for genre in brown.categories() 
  for word in brown.words(categories=genre)])
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cfd.tabulate(conditions=genres, samples=modals)
# Out:
#                   can could   may might  must  will
#            news    93    86    66    38    50   389
#        religion    82    59    78    12    54    71
#         hobbies   268    58   131    22    83   264
# science_fiction    16    49     4    12     8    16
#         romance    74   193    11    51    45    43
#           humor    16    30     8     8     9    13

# %% [markdown]
# ## 2.4 Reuters Corpus

# %%
from nltk.corpus import reuters
reuters.fileids()[:10]
# Out:
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843']

# %%
reuters.categories()[:10]
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee']

# %%
reuters.categories('training/9865')
# Out:
# ['barley', 'corn', 'grain', 'wheat']

# %%
reuters.categories(['training/9865', 'training/9880'])
# Out:
# ['barley', 'corn', 'grain', 'money-fx', 'wheat']

# %%
reuters.fileids('barley')[:10]
# Out:
# ['test/15618',
#  'test/15649',
#  'test/15676',
#  'test/15728',
#  'test/15871',
#  'test/15875',
#  'test/15952',
#  'test/17767',
#  'test/17769',
#  'test/18024']

# %%
reuters.fileids(['barley', 'corn'])[:10]
# Out:
# ['test/14832',
#  'test/14858',
#  'test/15033',
#  'test/15043',
#  'test/15106',
#  'test/15287',
#  'test/15341',
#  'test/15618',
#  'test/15648',
#  'test/15649']

# %%
reuters.words('training/9865')[:14]
# Out:
# ['FRENCH',
#  'FREE',
#  'MARKET',
#  'CEREAL',
#  'EXPORT',
#  'BIDS',
#  'DETAILED',
#  'French',
#  'operators',
#  'have',
#  'requested',
#  'licences',
#  'to',
#  'export']

# %%
reuters.words(categories=['barley', 'corn'])[:20]
# Out:
# ['THAI',
#  'TRADE',
#  'DEFICIT',
#  'WIDENS',
#  'IN',
#  'FIRST',
#  'QUARTER',
#  'Thailand',
#  "'",
#  's',
#  'trade',
#  'deficit',
#  'widened',
#  'to',
#  '4',
#  '.',
#  '5',
#  'billion',
#  'baht',
#  'in']

# %% [markdown]
# ## 2.5 Inaugural Address Corpus

# %%
from nltk.corpus import inaugural
inaugural.fileids()[:5]
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt']

# %%
output = []
for fileid in inaugural.fileids():
  for w in inaugural.words(fileid):
    for target in ['america', 'citizen']:
      if w.lower().startswith(target)]:
        value = (target, fileid[:4])
        output.append(value)

# %%
ax = plt.figure(figsize=(15,8))
ax.set_facecolor('white')
cfd = nltk.ConditionalFreqDist(
  [(target, fileid[:4])
  for fileid in inaugural.fileids()
  for w in inaugural.words(fileid)
  for target in ['america', 'citizen']
  if w.lower().startswith(target)]
)
cfd.plot()

# %% [markdown]
# ## 2.6 Annotated Text Corpora

# %% [markdown]
# ## 2.7  Corpora in Other Languages

# %%
nltk.corpus.cess_esp.words()
nltk.corpus.floresta.words()
nltk.corpus.indian.words('hindi.pos')
nltk.corpus.udhr.fileids()
nltk.corpus.udhr.words('Javanese-Latin1')[11:]

# %%
from nltk.corpus import udhr
languages = ['Chickasaw', 'English', 'German_Deutsch',
'Greenlandic_Inuktikut', 'Hungarian_Magyar', 'Ibibio_Efik']

ax = plt.figure(figsize=(15,8))
ax.set_facecolor('white')
cfd = nltk.ConditionalFreqDist(
  [(lang, len(word))
  for lang in languages
  for word in udhr.words(lang + '-Latin1')
  ]
)
cfd.plot(cumulative=True)

# %%
ax = plt.figure(figsize=(15,8))
ax.set_facecolor('white')
nltk.FreqDist(udhr.raw('English-Latin1')).plot()

# %% [markdown]
# ## 2.8 Text Corpus Structure
# ![text-corpus-structure[1].png](data:image/png;base64,...)

# %%
inaugural.abspath('1789-Washington.txt')
# Out:
# FileSystemPathPointer('/root/nltk_data/corpora/inaugural/1789-Washington.txt')

# %%
udhr.encoding('English-Latin1')
# Out:
# 'latin-1'

# %%
udhr.root
# Out:
# FileSystemPathPointer('/root/nltk_data/corpora/udhr')

# %%
inaugural.readme()
# Out:
# 'C-Span Inaugural Address Corpus\n\nUS presidential inaugural addresses 1789-2017\n\n(Thanks to Kathleen Ahrens for compiling this corpus from\nthe C-Span sources.)\n\n'

# %%
# gutenberg.raw("burgess-busterbrown.txt")
# gutenberg.words("burgess-busterbrown.txt")
# gutenberg.sents("burgess-busterbrown.txt")

# %% [markdown]
# ## 2.9 Loading your own Corpus

# %%
from nltk.corpus import PlaintextCorpusReader
corpus_root = '/usr/share/dict'
wordlists = PlaintextCorpusReader(corpus_root, '.*')
wordlists.fileids()
# wordlists.words('connectives')
# Out:
# []

# %%
from nltk.corpus import BracketParseCorpusReader
corpus_root = r"C:\corpora\penntreebank\parsed\mrg\wsj"
file_pattern = r".*/wsj_.*\.mrg"
ptb = BracketParseCorpusReader(corpus_root, file_pattern)
ptb.fileids()
